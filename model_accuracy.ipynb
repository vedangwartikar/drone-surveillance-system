# %% [markdown]
# ## Load necessary modules

# %%
# show images inline
# %matplotlib inline

# automatically reload modules when they have changed
# %load_ext autoreload
# %autoreload 2

# import keras
import keras

# import keras_retinanet
from keras_retinanet import models
from keras_retinanet.utils.image import read_image_bgr, preprocess_image, resize_image
from keras_retinanet.utils.visualization import draw_box, draw_caption
from keras_retinanet.utils.colors import label_color

# import miscellaneous modules
import matplotlib.pyplot as plt
import cv2
import os
import numpy as np
import time
import csv
# set tf backend to allow memory to grow, instead of claiming everything
import tensorflow as tf

def get_session():
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True
    return tf.Session(config=config)

# use this environment flag to change which GPU to use
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# set the modified tf session as backend in keras
keras.backend.tensorflow_backend.set_session(get_session())
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Using TensorFlow backend.

# %% [markdown]
# ## Load RetinaNet model

# %%
model_path = os.path.join('resnet50_csv_12_inference.h5')

# load retinanet model
model = models.load_model(model_path, backbone_name='resnet50')




# load label to names mapping for visualization purposes
labels_to_names = {0: 'Biker', 1: 'Car', 2: 'Bus', 3: 'Cart', 4: 'Skater', 5: 'Pedestrian'}
# labels_to_names = {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# Out:
# tracking <tf.Variable 'Variable:0' shape=(12, 4) dtype=float32> anchors
# tracking <tf.Variable 'Variable_1:0' shape=(12, 4) dtype=float32> anchors
# tracking <tf.Variable 'Variable_2:0' shape=(12, 4) dtype=float32> anchors
# tracking <tf.Variable 'Variable_3:0' shape=(12, 4) dtype=float32> anchors
# tracking <tf.Variable 'Variable_4:0' shape=(12, 4) dtype=float32> anchors
# WARNING:tensorflow:From C:\Users\Hp\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From C:\Users\Hp\Desktop\Persistent Project\Aerial Detection\keras_retinanet\backend\tensorflow_backend.py:68: The name tf.image.resize_images is deprecated. Please use tf.image.resize instead.
#
# WARNING:tensorflow:From C:\Users\Hp\Desktop\Persistent Project\Aerial Detection\keras_retinanet\backend\tensorflow_backend.py:104: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# C:\Users\Hp\Anaconda3\lib\site-packages\keras\engine\saving.py:341: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '

# %% [markdown]
# ### 1. Load CSV

# %%
annotations_file = 'test_annotations.csv'
cwd = os.getcwd()

image_names = []

with open (os.path.join(cwd, annotations_file)) as csvfile:
    readCSV = csv.reader(csvfile, delimiter='\n')
    for row in readCSV:
        vals = row[0].split(',')
        this_filepath = vals[0]
        image_names.append(this_filepath)
        
## remove duplicates by taking a set
image_names = list(set(image_names))
print(len(image_names))
# Out:
# 663

# %%
print(image_names[:2])
# Out:
# ['imgs/test/bookstore_video1_11460.jpg', 'imgs/test/quad_video2_330.jpg']

# %%
score_threshold_retinanet = 0.4
acceptable_box_overlap = 0.3

# %% [markdown]
# ### 2. Extract Ground Truth Annotations

# %%
def get_gt_annotations(filepath):
    gt_ann = []
    with open (os.path.join(cwd, annotations_file)) as csvfile:
        readCSV = csv.reader(csvfile, delimiter='\n')
        for row in readCSV:
            vals = row[0].split(',')
            this_filepath = vals[0]
            
            if this_filepath == filepath:
                record = []
                record.append(int(vals[1]))
                record.append(int(vals[2]))
                record.append(int(vals[3]))
                record.append(int(vals[4]))
                record.append(vals[5])
                
                gt_ann.append(record)
    return gt_ann

# %% [markdown]
# ### 3. IOU Calculations

# %%
def bb_intersection_over_union(boxA, boxB):
        # determine the (x, y)-coordinates of the intersection rectangle
        xA = max(int(boxA[0]), int(boxB[0]))
        yA = max(int(boxA[1]), int(boxB[1]))
        xB = min(int(boxA[2]), int(boxB[2]))
        yB = min(int(boxA[3]), int(boxB[3]))
 
        # compute the area of intersection rectangle
        interArea = max(0, xB - xA + 1) * max(0, yB - yA + 1)
 
        # compute the area of both the prediction and ground-truth
        # rectangles
        boxAArea = (int(boxA[2]) - int(boxA[0]) + 1) * (int(boxA[3]) - int(boxA[1]) + 1)
        boxBArea = (int(boxB[2]) - int(boxB[0]) + 1) * (int(boxB[3]) - int(boxB[1]) + 1)
 
        # compute the intersection over union by taking the intersection
        # area and dividing it by the sum of prediction + ground-truth
        # areas - the interesection area
        iou = interArea / float(boxAArea + boxBArea - interArea)
 
        # return the intersection over union value
        return iou

# %%
def highest_iou(predicted_box, gt_ann):
    
    highest_iou = 0
    best_match = []
    for each_gt in gt_ann:
        this_iou = bb_intersection_over_union(predicted_box[:-1], each_gt[:-1])
#         print(" For this box is: ", this_iou)
        if this_iou > highest_iou:
            highest_iou = this_iou
            best_match = each_gt
            
    return highest_iou, best_match

# %%
def accuracy(gt_ann, predicted_ann):
    true_positive = []
    class_mismatch = []
    false_positive = []
    false_negative = []
    
    predicted_ann_copy = predicted_ann.copy()
    gt_ann_copy = gt_ann.copy()
    
    for each_pred in predicted_ann_copy:
        # 1. Calculate the highest_iou with any gt_box
        best_iou, best_gt_match = highest_iou(each_pred, gt_ann_copy)
#         print("Best IOU is: ", each_pred, best_gt_match, best_iou)
        
        ## If this box has a match
        if best_iou >= acceptable_box_overlap:
            ## if class label matches
            if best_gt_match[-1] == each_pred[-1]:
                ## This is a true positive
                true_positive.append(each_pred)
                ## remove this from predicted ann and gt
#                 print("Predicted Ann before:", predicted_ann)
                predicted_ann.remove(each_pred)
#                 print("Predicted Ann after:", predicted_ann)
                if best_gt_match in gt_ann:
                    gt_ann.remove(best_gt_match)
            elif best_gt_match[-1] != each_pred[-1]:
                ## this is a class mismatch
                class_mismatch.append(each_pred)
                ## remove this box
                predicted_ann.remove(each_pred)
                if best_gt_match in gt_ann:
                    gt_ann.remove(best_gt_match)
        
    ## If IOU is less than 0.5, leave as is

    ## Any predicted box is now false positive
    for remain_pred in predicted_ann:
        false_positive.append(remain_pred)

    ## Any remaining gt box is false negative
    for remain_gt in gt_ann:
        if remain_gt[-1] in ['Biker', 'Pedestrian', 'Car', 'Bus']:
            false_negative.append(remain_gt)

    return true_positive, class_mismatch, false_positive, false_negative

# %% [markdown]
# ### 3. Draw Predicted and GT Annotations

# %%
def run_detection_image(filepath):
    image = read_image_bgr(filepath)

    # copy to draw on
    draw = image.copy()
    draw = cv2.cvtColor(draw, cv2.COLOR_BGR2RGB)

    # preprocess image for network
    image = preprocess_image(image)
    image, scale = resize_image(image)

    # process image
    start = time.time()
    boxes, scores, labels = model.predict_on_batch(np.expand_dims(image, axis=0))
    print("processing time: ", time.time() - start)

    # correct for image scale
    boxes /= scale
    
    gt_ann = get_gt_annotations(filepath)
    num_gt_ann = len(gt_ann)
    
    predicted_ann = []

    # visualize detections
    for box, score, label in zip(boxes[0], scores[0], labels[0]):
        # scores are sorted so we can break
        if score < score_threshold_retinanet:
            break
        record = []
        record.append(int(box[0]))
        record.append(int(box[1]))
        record.append(int(box[2]))
        record.append(int(box[3]))
        record.append(labels_to_names[label])
        print("Record is: ", record)
        predicted_ann.append(record)
    
    
#     print("predicted ann are: ", predicted_ann)
    ## Calculate boxes
    true_positive, class_mismatch, false_positive, false_negative = accuracy(gt_ann, predicted_ann)
    print(len(true_positive), len(class_mismatch), len(false_positive), len(false_negative))
    
    font = cv2.FONT_HERSHEY_SIMPLEX
    ## Draw theses on the image
    ## Draw true positive in green
    if len(true_positive) > 0:
        for each_true in true_positive:
            cv2.rectangle(draw,(each_true[0],each_true[1]),(each_true[2],each_true[3]),(0,255,0),3) #green
            cv2.putText(draw, each_true[-1], (each_true[0]-2, each_true[1]-2),font, 0.5,
                        (0,0,0),1,cv2.LINE_AA) # text in black
        
    ## Draw class mismatch in light blue   
    if len(class_mismatch) > 0:
        for each_mismatch in class_mismatch:
            cv2.rectangle(draw,(each_mismatch[0],each_mismatch[1]),(each_mismatch[2],each_mismatch[3]),(255,255,0),3) #green
            cv2.putText(draw, each_mismatch[-1], (each_mismatch[0]-2, each_mismatch[1]-2),font, 0.5,
                        (0,0,0),1,cv2.LINE_AA) # text in black
        
    
     ## Draw false positive  in blue 
    if len(false_positive) > 0:
        for each_fp in false_positive:
            cv2.rectangle(draw,(each_fp[0],each_fp[1]),(each_fp[2],each_fp[3]),(255,0,0),3) #green
            cv2.putText(draw, each_fp[-1], (each_fp[0]-2, each_fp[1]-2),font, 0.5,
                        (0,0,0),1,cv2.LINE_AA) # text in black
    
    
     ## Draw false negative in red 
    if len(false_negative) > 0:
        for each_fn in false_negative:
            cv2.rectangle(draw,(each_fn[0],each_fn[1]),(each_fn[2],each_fn[3]),(0,0,255),3) #green
            cv2.putText(draw, each_fn[-1], (each_fn[0]-2, each_fn[1]-2),font, 0.5,
                        (0,0,0),1,cv2.LINE_AA) # text in black
            
            
    ## Add key to the image
    cv2.putText(draw, "True Positive", (1200, 20),font, 0.8, (0,255,0),1,cv2.LINE_AA) 
    cv2.putText(draw, "Class Mismatch", (1200, 50),font, 0.8, (255,255,0),1,cv2.LINE_AA)
    cv2.putText(draw, "False Positive", (1200, 80),font, 0.8, (255,0,0),1,cv2.LINE_AA)
    cv2.putText(draw, "False Negtaive", (1200, 110),font, 0.8, (0,0,2550),1,cv2.LINE_AA)
    
    ### Save this image
    
    file, ext = os.path.splitext(filepath)
    image_name = file.split('/')[-1] + ext
    output_path = os.path.join('examples/results_test/', image_name)
    
    draw_conv = cv2.cvtColor(draw, cv2.COLOR_BGR2RGB)
    cv2.imwrite(output_path, draw_conv)
    
    return len(true_positive), len(class_mismatch), len(false_positive), len(false_negative), num_gt_ann

# %%
total_true_positive = 0
total_class_mismatch = 0
total_false_positive = 0
total_false_negative = 0
total_gt = 0

# %%
cnt=1
for filepath in image_names:
    num_tp, num_cm , num_fp, num_fn, num_gt = run_detection_image(filepath)
    print("Ground Truth: ", num_gt)
    total_true_positive += num_tp
    total_class_mismatch += num_cm
    total_false_positive += num_fp
    total_false_negative += num_fn
    total_gt += num_gt
    cnt+=1
    if cnt==80:
        break
# Out:
# WARNING:tensorflow:From C:\Users\Hp\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# processing time:  15.802170753479004
# Record is:  [1295, 721, 1327, 763, 'Pedestrian']
# Record is:  [1295, 1032, 1344, 1069, 'Pedestrian']
# Record is:  [1374, 203, 1409, 246, 'Pedestrian']
# Record is:  [212, 489, 247, 530, 'Pedestrian']
# Record is:  [696, 688, 730, 738, 'Pedestrian']
# Record is:  [297, 471, 336, 534, 'Biker']
# Record is:  [669, 345, 710, 384, 'Pedestrian']
# Record is:  [282, 462, 306, 511, 'Pedestrian']
# Record is:  [267, 168, 296, 202, 'Pedestrian']
# Record is:  [743, 259, 796, 324, 'Pedestrian']
# Record is:  [310, 429, 345, 481, 'Biker']
# 6 3 2 5
# Ground Truth:  14
# processing time:  3.221630573272705
# Record is:  [1622, 703, 1666, 733, 'Pedestrian']
# Record is:  [1775, 792, 1817, 830, 'Pedestrian']
# Record is:  [1908, 621, 1936, 644, 'Pedestrian']
# Record is:  [1726, 691, 1757, 715, 'Pedestrian']
# Record is:  [1887, 659, 1916, 681, 'Pedestrian']
# Record is:  [1804, 676, 1831, 705, 'Pedestrian']
# Record is:  [1733, 705, 1763, 729, 'Pedestrian']
# Record is:  [1767, 808, 1818, 840, 'Pedestrian']
# Record is:  [1630, 656, 1661, 685, 'Pedestrian']
# Record is:  [1931, 487, 1965, 515, 'Pedestrian']
# Record is:  [473, 10, 535, 37, 'Pedestrian']
# Record is:  [1895, 652, 1923, 674, 'Pedestrian']
# Record is:  [1907, 652, 1934, 673, 'Pedestrian']
# Record is:  [1380, 691, 1415, 720, 'Biker']
# Record is:  [1765, 795, 1804, 828, 'Pedestrian']
# Record is:  [1908, 636, 1934, 657, 'Pedestrian']
# Record is:  [1370, 680, 1415, 727, 'Biker']
# Record is:  [1874, 658, 1905, 682, 'Pedestrian']
# Record is:  [1370, 681, 1415, 726, 'Pedestrian']
# 16 2 1 1
# Ground Truth:  13
# processing time:  2.68302321434021
# Record is:  [1133, 603, 1168, 643, 'Pedestrian']
# Record is:  [1374, 204, 1410, 251, 'Pedestrian']
# Record is:  [424, 656, 465, 721, 'Pedestrian']
# Record is:  [695, 340, 735, 387, 'Pedestrian']
# Record is:  [310, 1036, 358, 1072, 'Pedestrian']
# Record is:  [302, 1025, 354, 1070, 'Biker']
# Record is:  [460, 358, 500, 401, 'Pedestrian']
# Record is:  [428, 640, 459, 701, 'Pedestrian']
# Record is:  [244, 459, 270, 501, 'Pedestrian']
# 4 3 2 8
# Ground Truth:  13
# processing time:  3.0834076404571533
# Record is:  [1327, 144, 1376, 184, 'Pedestrian']
# Record is:  [1293, 152, 1332, 187, 'Pedestrian']
# Record is:  [1436, 121, 1490, 164, 'Pedestrian']
# Record is:  [1412, 145, 1467, 194, 'Pedestrian']
# Record is:  [1331, 111, 1381, 152, 'Pedestrian']
# Record is:  [578, 344, 663, 410, 'Pedestrian']
# Record is:  [406, 358, 479, 418, 'Pedestrian']
# Record is:  [1406, 186, 1466, 233, 'Pedestrian']
# Record is:  [1295, 105, 1331, 153, 'Pedestrian']
# Record is:  [1276, 51, 1333, 103, 'Pedestrian']
# Record is:  [783, 931, 846, 983, 'Pedestrian']
# Record is:  [1362, 68, 1410, 123, 'Pedestrian']
# Record is:  [220, 719, 294, 774, 'Pedestrian']
# Record is:  [1031, 449, 1119, 519, 'Biker']
# Record is:  [1453, 437, 1513, 494, 'Pedestrian']
# Record is:  [1332, 125, 1380, 168, 'Pedestrian']
# Record is:  [1341, 76, 1385, 123, 'Pedestrian']
# 17 0 0 0
# Ground Truth:  15
# processing time:  3.0690431594848633
# Record is:  [1288, 150, 1330, 188, 'Pedestrian']
# Record is:  [1329, 108, 1376, 149, 'Pedestrian']
# Record is:  [1326, 143, 1374, 181, 'Pedestrian']
# Record is:  [1293, 110, 1333, 150, 'Pedestrian']
# Record is:  [1409, 145, 1466, 201, 'Pedestrian']
# Record is:  [1436, 119, 1498, 163, 'Pedestrian']
# Record is:  [1456, 45, 1517, 97, 'Pedestrian']
# Record is:  [1274, 51, 1323, 103, 'Pedestrian']
# Record is:  [403, 353, 482, 416, 'Pedestrian']
# Record is:  [584, 350, 662, 410, 'Pedestrian']
# Record is:  [1241, 432, 1327, 510, 'Biker']
# Record is:  [910, 931, 974, 1001, 'Pedestrian']
# 12 0 0 1
# Ground Truth:  13
# processing time:  3.11800479888916
# Record is:  [1287, 152, 1332, 194, 'Pedestrian']
# Record is:  [1324, 144, 1380, 184, 'Pedestrian']
# Record is:  [1431, 118, 1491, 162, 'Pedestrian']
# Record is:  [1329, 110, 1373, 151, 'Pedestrian']
# Record is:  [1269, 50, 1325, 102, 'Pedestrian']
# Record is:  [1406, 142, 1465, 190, 'Pedestrian']
# Record is:  [1297, 104, 1336, 153, 'Pedestrian']
# Record is:  [403, 355, 474, 419, 'Pedestrian']
# Record is:  [1120, 1005, 1175, 1051, 'Pedestrian']
# Record is:  [1455, 487, 1530, 546, 'Biker']
# Record is:  [578, 347, 669, 411, 'Pedestrian']
# Record is:  [1453, 464, 1545, 538, 'Car']
# 11 1 0 0
# Ground Truth:  11
# processing time:  4.127455472946167
# Record is:  [106, 981, 169, 1066, 'Biker']
# Record is:  [1267, 1614, 1300, 1711, 'Pedestrian']
# Record is:  [1167, 1177, 1219, 1273, 'Pedestrian']
# 3 0 0 0
# Ground Truth:  3
# processing time:  3.0780909061431885
# Record is:  [689, 693, 750, 782, 'Pedestrian']
# Record is:  [1193, 1091, 1224, 1159, 'Pedestrian']
# Record is:  [1050, 837, 1126, 957, 'Pedestrian']
# Record is:  [1050, 838, 1126, 958, 'Biker']
# Record is:  [925, 1789, 983, 1877, 'Biker']
# Record is:  [1160, 1210, 1215, 1289, 'Pedestrian']
# 5 1 0 0
# Ground Truth:  5
# processing time:  4.422111511230469
# Record is:  [1280, 151, 1331, 194, 'Pedestrian']
# Record is:  [1433, 119, 1490, 162, 'Pedestrian']
# Record is:  [1321, 145, 1380, 186, 'Pedestrian']
# Record is:  [1405, 142, 1463, 185, 'Pedestrian']
# Record is:  [1261, 49, 1332, 105, 'Pedestrian']
# Record is:  [1271, 121, 1317, 169, 'Pedestrian']
# Record is:  [1329, 108, 1372, 153, 'Pedestrian']
# Record is:  [399, 351, 474, 418, 'Pedestrian']
# Record is:  [1479, 482, 1569, 557, 'Pedestrian']
# Record is:  [577, 341, 673, 409, 'Pedestrian']
# 10 0 0 0
# Ground Truth:  10
# processing time:  3.838484048843384
# Record is:  [1329, 143, 1376, 185, 'Pedestrian']
# Record is:  [1438, 119, 1497, 163, 'Pedestrian']
# Record is:  [1283, 153, 1339, 196, 'Pedestrian']
# Record is:  [1330, 108, 1377, 152, 'Pedestrian']
# Record is:  [1562, 941, 1656, 1021, 'Pedestrian']
# Record is:  [413, 352, 496, 421, 'Pedestrian']
# Record is:  [1400, 149, 1467, 205, 'Pedestrian']
# Record is:  [1203, 750, 1307, 807, 'Pedestrian']
# Record is:  [1269, 47, 1334, 98, 'Pedestrian']
# Record is:  [1381, 201, 1448, 252, 'Pedestrian']
# Record is:  [1586, 719, 1687, 794, 'Pedestrian']
# Record is:  [1414, 151, 1465, 186, 'Pedestrian']
# Record is:  [577, 344, 663, 411, 'Pedestrian']
# Record is:  [1731, 867, 1853, 943, 'Biker']
# Record is:  [98, 664, 154, 748, 'Pedestrian']
# Record is:  [1395, 164, 1461, 221, 'Pedestrian']
# Record is:  [1279, 121, 1326, 165, 'Pedestrian']
# Record is:  [1274, 133, 1329, 179, 'Pedestrian']
# Record is:  [963, 449, 1030, 517, 'Pedestrian']
# Record is:  [982, 479, 1050, 543, 'Pedestrian']
# 20 0 0 1
# Ground Truth:  19
# processing time:  3.726526975631714
# Record is:  [1264, 1623, 1299, 1704, 'Pedestrian']
# Record is:  [1122, 964, 1185, 1047, 'Biker']
# Record is:  [798, 871, 850, 948, 'Biker']
# Record is:  [933, 1009, 979, 1099, 'Pedestrian']
# 4 0 0 0
# Ground Truth:  4
# processing time:  3.4401142597198486
# Record is:  [262, 611, 292, 663, 'Pedestrian']
# Record is:  [918, 963, 948, 1007, 'Pedestrian']
# Record is:  [763, 264, 817, 314, 'Pedestrian']
# Record is:  [301, 348, 353, 395, 'Biker']
# Record is:  [688, 327, 727, 381, 'Pedestrian']
# Record is:  [463, 368, 505, 410, 'Pedestrian']
# Record is:  [94, 1017, 157, 1071, 'Pedestrian']
# Record is:  [1392, 537, 1421, 578, 'Pedestrian']
# Record is:  [180, 584, 215, 635, 'Pedestrian']
# Record is:  [905, 961, 935, 1005, 'Pedestrian']
# Record is:  [27, 896, 88, 946, 'Pedestrian']
# Record is:  [463, 657, 532, 726, 'Bus']
# 9 0 3 10
# Ground Truth:  18
# processing time:  3.411147356033325
# Record is:  [278, 812, 330, 913, 'Biker']
# Record is:  [466, 845, 522, 959, 'Biker']
# Record is:  [1171, 1717, 1229, 1798, 'Pedestrian']
# Record is:  [1043, 1709, 1124, 1822, 'Pedestrian']
# Record is:  [1054, 1709, 1117, 1813, 'Biker']
# 4 1 0 0
# Ground Truth:  4
# processing time:  3.763007879257202
# Record is:  [1265, 284, 1306, 346, 'Pedestrian']
# Record is:  [696, 334, 737, 385, 'Pedestrian']
# Record is:  [1281, 989, 1329, 1041, 'Biker']
# Record is:  [306, 795, 351, 850, 'Biker']
# Record is:  [1374, 204, 1407, 244, 'Pedestrian']
# Record is:  [892, 855, 916, 893, 'Pedestrian']
# Record is:  [1215, 767, 1262, 819, 'Biker']
# Record is:  [693, 688, 725, 735, 'Pedestrian']
# Record is:  [475, 1027, 533, 1071, 'Biker']
# Record is:  [9, 466, 40, 507, 'Pedestrian']
# Record is:  [6, 471, 55, 517, 'Pedestrian']
# Record is:  [491, 1037, 539, 1075, 'Pedestrian']
# Record is:  [739, 260, 797, 318, 'Pedestrian']
# Record is:  [100, 1019, 151, 1068, 'Pedestrian']
# 9 2 3 6
# Ground Truth:  16
# processing time:  3.8102996349334717
# Record is:  [1278, 52, 1328, 94, 'Pedestrian']
# Record is:  [1327, 146, 1375, 184, 'Pedestrian']
# Record is:  [1288, 147, 1335, 193, 'Pedestrian']
# Record is:  [1331, 112, 1374, 150, 'Pedestrian']
# Record is:  [1280, 84, 1331, 126, 'Pedestrian']
# Record is:  [1285, 117, 1336, 157, 'Pedestrian']
# Record is:  [1444, 102, 1523, 162, 'Pedestrian']
# Record is:  [587, 363, 639, 411, 'Pedestrian']
# Record is:  [1409, 142, 1461, 201, 'Pedestrian']
# Record is:  [1466, 733, 1518, 777, 'Pedestrian']
# Record is:  [1040, 837, 1099, 891, 'Pedestrian']
# Record is:  [1034, 883, 1094, 930, 'Pedestrian']
# 12 0 0 0
# Ground Truth:  12
# processing time:  3.6627650260925293
# Record is:  [706, 315, 736, 366, 'Pedestrian']
# Record is:  [1372, 968, 1405, 995, 'Pedestrian']
# Record is:  [591, 1024, 642, 1074, 'Biker']
# Record is:  [269, 277, 307, 333, 'Biker']
# Record is:  [1371, 977, 1403, 1003, 'Pedestrian']
# 3 1 1 3
# Ground Truth:  7
# processing time:  4.1487274169921875
# Record is:  [1325, 140, 1373, 177, 'Pedestrian']
# Record is:  [1270, 144, 1330, 189, 'Pedestrian']
# Record is:  [1325, 109, 1384, 149, 'Pedestrian']
# Record is:  [1113, 951, 1186, 1016, 'Pedestrian']
# Record is:  [1291, 111, 1337, 151, 'Pedestrian']
# Record is:  [1288, 86, 1330, 126, 'Pedestrian']
# Record is:  [1406, 152, 1462, 201, 'Pedestrian']
# Record is:  [1210, 540, 1290, 616, 'Pedestrian']
# Record is:  [1437, 113, 1497, 161, 'Pedestrian']
# Record is:  [1115, 917, 1183, 969, 'Pedestrian']
# Record is:  [1267, 45, 1333, 91, 'Pedestrian']
# Record is:  [761, 270, 869, 337, 'Pedestrian']
# Record is:  [1888, 891, 1961, 966, 'Biker']
# Record is:  [1444, 728, 1524, 784, 'Pedestrian']
# Record is:  [1742, 801, 1825, 871, 'Pedestrian']
# 15 0 0 0
# Ground Truth:  15
# processing time:  3.424197196960449
# Record is:  [1275, 1032, 1324, 1069, 'Pedestrian']
# Record is:  [691, 358, 741, 407, 'Pedestrian']
# Record is:  [1377, 207, 1409, 244, 'Pedestrian']
# Record is:  [1235, 523, 1268, 570, 'Pedestrian']
# Record is:  [696, 689, 731, 730, 'Pedestrian']
# Record is:  [468, 655, 532, 727, 'Bus']
# Record is:  [273, 184, 314, 253, 'Biker']
# Record is:  [392, 517, 457, 584, 'Biker']
# Record is:  [311, 906, 340, 947, 'Pedestrian']
# Record is:  [461, 352, 500, 408, 'Pedestrian']
# Record is:  [736, 267, 790, 312, 'Pedestrian']
# 6 2 3 4
# Ground Truth:  12
# processing time:  3.991170883178711
# Record is:  [1278, 1611, 1304, 1721, 'Pedestrian']
# Record is:  [109, 1212, 151, 1282, 'Pedestrian']
# Record is:  [1009, 1147, 1047, 1230, 'Pedestrian']
# Record is:  [1019, 1135, 1056, 1221, 'Pedestrian']
# 4 0 0 0
# Ground Truth:  3
# processing time:  3.931647539138794
# Record is:  [268, 974, 336, 1064, 'Biker']
# Record is:  [886, 850, 936, 926, 'Biker']
# Record is:  [1122, 839, 1177, 919, 'Biker']
# 3 0 0 0
# Ground Truth:  3
# processing time:  3.4911270141601562
# Record is:  [733, 1139, 780, 1229, 'Pedestrian']
# Record is:  [791, 717, 839, 838, 'Pedestrian']
# Record is:  [748, 1143, 808, 1243, 'Pedestrian']
# 3 0 0 0
# Ground Truth:  2
# processing time:  3.613123655319214
# Record is:  [1278, 646, 1320, 701, 'Pedestrian']
# Record is:  [740, 268, 793, 318, 'Pedestrian']
# Record is:  [916, 562, 954, 606, 'Pedestrian']
# Record is:  [305, 798, 346, 853, 'Biker']
# Record is:  [640, 332, 685, 384, 'Pedestrian']
# Record is:  [1367, 202, 1406, 248, 'Pedestrian']
# Record is:  [691, 685, 726, 737, 'Pedestrian']
# Record is:  [628, 884, 682, 952, 'Pedestrian']
# Record is:  [205, 485, 251, 532, 'Pedestrian']
# 6 1 2 7
# Ground Truth:  14
# processing time:  3.8738133907318115
# Record is:  [1331, 143, 1366, 176, 'Pedestrian']
# Record is:  [1290, 160, 1336, 193, 'Pedestrian']
# Record is:  [1332, 108, 1377, 140, 'Pedestrian']
# Record is:  [1291, 117, 1333, 151, 'Pedestrian']
# Record is:  [1291, 90, 1335, 116, 'Pedestrian']
# Record is:  [1439, 114, 1503, 160, 'Pedestrian']
# Record is:  [583, 352, 647, 411, 'Pedestrian']
# Record is:  [1402, 154, 1466, 210, 'Pedestrian']
# Record is:  [1453, 739, 1510, 777, 'Pedestrian']
# Record is:  [1290, 54, 1333, 89, 'Pedestrian']
# Record is:  [1418, 158, 1462, 193, 'Pedestrian']
# Record is:  [426, 956, 469, 1004, 'Pedestrian']
# Record is:  [516, 915, 590, 966, 'Pedestrian']
# Record is:  [415, 365, 475, 413, 'Pedestrian']
# 14 0 0 0
# Ground Truth:  14
# processing time:  4.585804462432861
# Record is:  [1289, 152, 1332, 189, 'Pedestrian']
# Record is:  [1326, 141, 1369, 175, 'Pedestrian']
# Record is:  [1333, 111, 1372, 148, 'Pedestrian']
# Record is:  [1289, 117, 1333, 152, 'Pedestrian']
# Record is:  [1278, 55, 1329, 92, 'Pedestrian']
# Record is:  [1415, 149, 1463, 192, 'Pedestrian']
# Record is:  [1439, 116, 1496, 162, 'Pedestrian']
# Record is:  [1453, 741, 1509, 775, 'Pedestrian']
# Record is:  [386, 952, 447, 1005, 'Pedestrian']
# Record is:  [479, 912, 552, 968, 'Pedestrian']
# Record is:  [1424, 1, 1484, 43, 'Pedestrian']
# Record is:  [581, 351, 643, 409, 'Pedestrian']
# 12 0 0 3
# Ground Truth:  15
# processing time:  3.4444570541381836
# Record is:  [306, 797, 350, 853, 'Biker']
# Record is:  [1258, 661, 1302, 719, 'Pedestrian']
# Record is:  [1262, 967, 1306, 1003, 'Pedestrian']
# Record is:  [956, 562, 988, 600, 'Pedestrian']
# Record is:  [667, 890, 720, 956, 'Pedestrian']
# Record is:  [691, 692, 725, 741, 'Pedestrian']
# Record is:  [791, 294, 831, 340, 'Pedestrian']
# Record is:  [650, 334, 694, 393, 'Pedestrian']
# Record is:  [743, 265, 796, 313, 'Pedestrian']
# Record is:  [293, 869, 324, 916, 'Pedestrian']
# Record is:  [1380, 202, 1407, 246, 'Pedestrian']
# 5 1 5 9
# Ground Truth:  15
# processing time:  3.4623444080352783
# Record is:  [897, 454, 942, 508, 'Pedestrian']
# Record is:  [1370, 205, 1408, 249, 'Pedestrian']
# Record is:  [598, 469, 643, 513, 'Pedestrian']
# Record is:  [708, 348, 750, 395, 'Pedestrian']
# Record is:  [1155, 884, 1180, 934, 'Pedestrian']
# Record is:  [1044, 880, 1073, 923, 'Pedestrian']
# Record is:  [997, 1028, 1062, 1069, 'Biker']
# Record is:  [463, 351, 496, 401, 'Pedestrian']
# Record is:  [1032, 871, 1069, 918, 'Pedestrian']
# Record is:  [1276, 964, 1328, 1007, 'Biker']
# Record is:  [741, 273, 790, 314, 'Pedestrian']
# 8 1 2 7
# Ground Truth:  16
# processing time:  4.516706228256226
# Record is:  [1322, 145, 1378, 185, 'Pedestrian']
# Record is:  [1272, 150, 1329, 192, 'Pedestrian']
# Record is:  [1433, 118, 1491, 163, 'Pedestrian']
# Record is:  [1408, 144, 1463, 192, 'Pedestrian']
# Record is:  [1264, 49, 1335, 101, 'Pedestrian']
# Record is:  [1273, 115, 1319, 160, 'Pedestrian']
# Record is:  [1330, 108, 1374, 151, 'Pedestrian']
# Record is:  [404, 350, 489, 415, 'Pedestrian']
# Record is:  [576, 337, 673, 409, 'Pedestrian']
# Record is:  [1217, 940, 1299, 988, 'Biker']
# Record is:  [1182, 931, 1314, 1000, 'Biker']
# Record is:  [698, 806, 777, 852, 'Biker']
# 12 0 0 0
# Ground Truth:  11
# processing time:  3.7760045528411865
# Record is:  [1288, 147, 1331, 192, 'Pedestrian']
# Record is:  [1270, 51, 1329, 95, 'Pedestrian']
# Record is:  [1326, 148, 1377, 186, 'Pedestrian']
# Record is:  [1279, 84, 1331, 124, 'Pedestrian']
# Record is:  [1409, 139, 1468, 202, 'Pedestrian']
# Record is:  [1285, 117, 1340, 157, 'Pedestrian']
# Record is:  [1333, 109, 1378, 149, 'Pedestrian']
# Record is:  [589, 363, 640, 410, 'Pedestrian']
# Record is:  [619, 843, 681, 892, 'Pedestrian']
# Record is:  [1426, 116, 1494, 164, 'Pedestrian']
# Record is:  [428, 374, 473, 414, 'Pedestrian']
# Record is:  [607, 792, 672, 844, 'Pedestrian']
# Record is:  [115, 863, 183, 942, 'Biker']
# Record is:  [1356, 565, 1449, 628, 'Pedestrian']
# Record is:  [1453, 739, 1511, 775, 'Pedestrian']
# Record is:  [1333, 550, 1422, 626, 'Pedestrian']
# 15 0 1 0
# Ground Truth:  14
# processing time:  3.6883482933044434
# Record is:  [1322, 139, 1373, 177, 'Pedestrian']
# Record is:  [1266, 142, 1329, 186, 'Pedestrian']
# Record is:  [1330, 108, 1379, 150, 'Pedestrian']
# Record is:  [1406, 150, 1466, 203, 'Pedestrian']
# Record is:  [1282, 84, 1328, 127, 'Pedestrian']
# Record is:  [1291, 110, 1338, 151, 'Pedestrian']
# Record is:  [1261, 41, 1331, 93, 'Pedestrian']
# Record is:  [1434, 111, 1495, 163, 'Pedestrian']
# Record is:  [1480, 799, 1561, 875, 'Pedestrian']
# Record is:  [929, 197, 1016, 253, 'Pedestrian']
# Record is:  [1314, 908, 1388, 967, 'Pedestrian']
# Record is:  [1204, 67, 1263, 116, 'Pedestrian']
# Record is:  [1297, 943, 1374, 1012, 'Pedestrian']
# Record is:  [1448, 728, 1517, 781, 'Pedestrian']
# 13 0 1 0
# Ground Truth:  13
# processing time:  3.779629945755005
# Record is:  [1163, 980, 1230, 1077, 'Biker']
# Record is:  [169, 887, 229, 954, 'Biker']
# Record is:  [158, 1154, 227, 1227, 'Pedestrian']
# Record is:  [344, 985, 412, 1081, 'Biker']
# Record is:  [60, 832, 109, 908, 'Biker']
# Record is:  [114, 823, 162, 896, 'Biker']
# 5 0 1 0
# Ground Truth:  5
# processing time:  4.47433614730835
# Record is:  [1322, 138, 1378, 178, 'Pedestrian']
# Record is:  [1335, 108, 1385, 150, 'Pedestrian']
# Record is:  [1277, 141, 1337, 185, 'Pedestrian']
# Record is:  [1289, 113, 1337, 152, 'Pedestrian']
# Record is:  [1270, 84, 1337, 122, 'Pedestrian']
# Record is:  [1437, 107, 1499, 163, 'Pedestrian']
# Record is:  [1286, 37, 1342, 96, 'Pedestrian']
# Record is:  [1551, 734, 1660, 806, 'Pedestrian']
# Record is:  [834, 782, 906, 863, 'Pedestrian']
# Record is:  [438, 928, 529, 1003, 'Biker']
# Record is:  [1406, 143, 1476, 203, 'Pedestrian']
# Record is:  [1806, 962, 1894, 1022, 'Pedestrian']
# Record is:  [1206, 66, 1265, 117, 'Pedestrian']
# Record is:  [1376, 277, 1502, 327, 'Pedestrian']
# Record is:  [1691, 776, 1798, 840, 'Pedestrian']
# Record is:  [1446, 730, 1517, 785, 'Pedestrian']
# Record is:  [1554, 744, 1657, 812, 'Biker']
# Record is:  [1800, 935, 1918, 980, 'Pedestrian']
# 16 1 1 0
# Ground Truth:  16
# processing time:  3.7479331493377686
# Record is:  [723, 1038, 825, 1132, 'Biker']
# Record is:  [279, 822, 346, 901, 'Biker']
# Record is:  [459, 984, 537, 1084, 'Biker']
# 2 1 0 0
# Ground Truth:  3
# processing time:  3.560255765914917
# Record is:  [910, 455, 961, 509, 'Pedestrian']
# Record is:  [1261, 605, 1314, 656, 'Biker']
# Record is:  [1150, 403, 1187, 454, 'Pedestrian']
# Record is:  [1372, 202, 1405, 249, 'Pedestrian']
# Record is:  [271, 291, 298, 327, 'Pedestrian']
# Record is:  [518, 875, 568, 931, 'Biker']
# Record is:  [1205, 747, 1241, 782, 'Pedestrian']
# Record is:  [328, 866, 369, 914, 'Biker']
# Record is:  [701, 330, 738, 376, 'Pedestrian']
# Record is:  [1325, 795, 1386, 851, 'Pedestrian']
# Record is:  [458, 355, 497, 405, 'Pedestrian']
# Record is:  [301, 854, 368, 912, 'Biker']
# Record is:  [134, 345, 190, 398, 'Pedestrian']
# Record is:  [767, 286, 809, 330, 'Pedestrian']
# Record is:  [271, 943, 303, 985, 'Pedestrian']
# 9 2 4 7
# Ground Truth:  17
# processing time:  4.298897743225098
# Record is:  [1283, 149, 1331, 187, 'Pedestrian']
# Record is:  [1290, 115, 1333, 153, 'Pedestrian']
# Record is:  [1333, 144, 1368, 178, 'Pedestrian']
# Record is:  [1332, 108, 1376, 148, 'Pedestrian']
# Record is:  [1279, 84, 1328, 121, 'Pedestrian']
# Record is:  [1409, 147, 1466, 204, 'Pedestrian']
# Record is:  [1435, 110, 1500, 161, 'Pedestrian']
# Record is:  [586, 363, 638, 408, 'Pedestrian']
# Record is:  [1271, 59, 1324, 100, 'Pedestrian']
# Record is:  [252, 922, 303, 958, 'Pedestrian']
# Record is:  [1298, 309, 1376, 391, 'Pedestrian']
# Record is:  [1449, 738, 1510, 777, 'Pedestrian']
# Record is:  [215, 947, 272, 986, 'Pedestrian']
# Record is:  [1382, 670, 1437, 718, 'Pedestrian']
# 10 2 2 0
# Ground Truth:  11
# processing time:  3.9184296131134033
# Record is:  [1290, 150, 1333, 189, 'Pedestrian']
# Record is:  [1329, 111, 1371, 149, 'Pedestrian']
# Record is:  [1329, 142, 1369, 176, 'Pedestrian']
# Record is:  [1277, 53, 1330, 92, 'Pedestrian']
# Record is:  [1289, 113, 1329, 151, 'Pedestrian']
# Record is:  [1417, 145, 1461, 191, 'Pedestrian']
# Record is:  [1497, 916, 1565, 953, 'Pedestrian']
# Record is:  [1442, 113, 1501, 163, 'Pedestrian']
# Record is:  [1507, 875, 1575, 920, 'Pedestrian']
# Record is:  [1468, 733, 1519, 775, 'Pedestrian']
# Record is:  [585, 363, 639, 407, 'Pedestrian']
# Record is:  [231, 899, 295, 935, 'Biker']
# Record is:  [206, 871, 300, 964, 'Biker']
# Record is:  [1287, 87, 1327, 122, 'Pedestrian']
# 13 0 1 0
# Ground Truth:  12
# processing time:  4.567898511886597
# Record is:  [1277, 1612, 1305, 1719, 'Pedestrian']
# Record is:  [1136, 1149, 1175, 1237, 'Pedestrian']
# Record is:  [54, 1213, 101, 1283, 'Pedestrian']
# 3 0 0 0
# Ground Truth:  3
# processing time:  3.4582204818725586
# Record is:  [694, 336, 734, 390, 'Pedestrian']
# Record is:  [239, 710, 269, 772, 'Pedestrian']
# Record is:  [399, 503, 453, 557, 'Pedestrian']
# Record is:  [900, 663, 931, 714, 'Pedestrian']
# Record is:  [1223, 1025, 1271, 1066, 'Biker']
# Record is:  [764, 271, 804, 322, 'Pedestrian']
# 4 2 0 9
# Ground Truth:  15
# processing time:  4.447990417480469
# Record is:  [1290, 120, 1333, 151, 'Pedestrian']
# Record is:  [1331, 109, 1378, 140, 'Pedestrian']
# Record is:  [1289, 90, 1335, 116, 'Pedestrian']
# Record is:  [1332, 143, 1367, 175, 'Pedestrian']
# Record is:  [1292, 162, 1340, 196, 'Pedestrian']
# Record is:  [1442, 112, 1504, 156, 'Pedestrian']
# Record is:  [1453, 740, 1510, 777, 'Pedestrian']
# Record is:  [1293, 56, 1331, 89, 'Pedestrian']
# Record is:  [584, 353, 650, 413, 'Pedestrian']
# Record is:  [1407, 158, 1467, 211, 'Pedestrian']
# Record is:  [1418, 156, 1462, 192, 'Pedestrian']
# Record is:  [581, 919, 656, 958, 'Pedestrian']
# Record is:  [489, 939, 538, 994, 'Pedestrian']
# Record is:  [416, 363, 476, 414, 'Pedestrian']
# Record is:  [215, 654, 302, 704, 'Pedestrian']
# Record is:  [215, 654, 302, 704, 'Biker']
# 15 1 0 0
# Ground Truth:  15
# processing time:  4.093238353729248
# Record is:  [1288, 149, 1328, 185, 'Pedestrian']
# Record is:  [1326, 144, 1369, 182, 'Pedestrian']
# Record is:  [1290, 112, 1330, 153, 'Pedestrian']
# Record is:  [1331, 108, 1376, 149, 'Pedestrian']
# Record is:  [1410, 146, 1467, 196, 'Pedestrian']
# Record is:  [405, 352, 489, 417, 'Pedestrian']
# Record is:  [1441, 119, 1492, 163, 'Pedestrian']
# Record is:  [586, 363, 639, 409, 'Pedestrian']
# Record is:  [1269, 55, 1326, 105, 'Pedestrian']
# Record is:  [1328, 887, 1403, 959, 'Pedestrian']
# Record is:  [497, 958, 568, 1007, 'Pedestrian']
# Record is:  [1387, 55, 1426, 107, 'Pedestrian']
# Record is:  [597, 574, 661, 630, 'Biker']
# Record is:  [1363, 76, 1400, 120, 'Pedestrian']
# 13 0 1 2
# Ground Truth:  15
# processing time:  4.657760381698608
# Record is:  [884, 813, 945, 897, 'Biker']
# Record is:  [946, 1117, 1011, 1164, 'Pedestrian']
# Record is:  [952, 1148, 1009, 1203, 'Pedestrian']
# Record is:  [94, 902, 143, 965, 'Biker']
# Record is:  [115, 899, 164, 965, 'Biker']
# 5 0 0 0
# Ground Truth:  4
# processing time:  4.0578343868255615
# Record is:  [430, 1120, 480, 1214, 'Pedestrian']
# Record is:  [538, 875, 586, 976, 'Pedestrian']
# 2 0 0 0
# Ground Truth:  2
# processing time:  4.537269592285156
# Record is:  [1181, 1728, 1268, 1827, 'Pedestrian']
# Record is:  [1088, 722, 1135, 819, 'Pedestrian']
# 2 0 0 0
# Ground Truth:  2
# processing time:  3.6055197715759277
# Record is:  [373, 756, 424, 811, 'Biker']
# Record is:  [691, 1020, 747, 1070, 'Biker']
# Record is:  [380, 335, 404, 380, 'Biker']
# Record is:  [715, 337, 768, 388, 'Pedestrian']
# Record is:  [304, 794, 351, 850, 'Biker']
# Record is:  [763, 270, 804, 318, 'Pedestrian']
# Record is:  [457, 1021, 508, 1072, 'Biker']
# Record is:  [692, 689, 722, 737, 'Pedestrian']
# Record is:  [790, 857, 823, 898, 'Pedestrian']
# Record is:  [744, 266, 792, 315, 'Pedestrian']
# Record is:  [1368, 255, 1411, 325, 'Pedestrian']
# 7 2 2 5
# Ground Truth:  14
# processing time:  3.7867844104766846
# Record is:  [936, 854, 997, 923, 'Biker']
# Record is:  [438, 984, 510, 1082, 'Biker']
# Record is:  [0, 1143, 30, 1223, 'Pedestrian']
# Record is:  [715, 849, 768, 920, 'Biker']
# 4 0 0 0
# Ground Truth:  4
# processing time:  4.701509475708008
# Record is:  [328, 1129, 380, 1233, 'Pedestrian']
# Record is:  [484, 959, 529, 1062, 'Pedestrian']
# 2 0 0 0
# Ground Truth:  2
# processing time:  3.438751697540283
# Record is:  [694, 335, 736, 387, 'Pedestrian']
# Record is:  [1009, 915, 1047, 957, 'Pedestrian']
# Record is:  [273, 575, 303, 623, 'Pedestrian']
# Record is:  [10, 951, 38, 998, 'Pedestrian']
# Record is:  [681, 974, 726, 1033, 'Biker']
# Record is:  [204, 698, 235, 753, 'Pedestrian']
# Record is:  [98, 1019, 153, 1072, 'Pedestrian']
# Record is:  [104, 818, 142, 872, 'Pedestrian']
# 5 2 1 8
# Ground Truth:  15
# processing time:  4.293695688247681
# Record is:  [1292, 151, 1332, 187, 'Pedestrian']
# Record is:  [1328, 112, 1371, 149, 'Pedestrian']
# Record is:  [1280, 53, 1329, 91, 'Pedestrian']
# Record is:  [1328, 142, 1368, 175, 'Pedestrian']
# Record is:  [1290, 114, 1328, 150, 'Pedestrian']
# Record is:  [1417, 146, 1463, 190, 'Pedestrian']
# Record is:  [1445, 111, 1499, 163, 'Pedestrian']
# Record is:  [584, 365, 639, 406, 'Pedestrian']
# Record is:  [1466, 734, 1518, 776, 'Pedestrian']
# Record is:  [1588, 916, 1659, 959, 'Pedestrian']
# Record is:  [491, 893, 551, 931, 'Biker']
# Record is:  [1591, 882, 1660, 923, 'Pedestrian']
# Record is:  [455, 872, 562, 968, 'Biker']
# Record is:  [495, 893, 550, 930, 'Pedestrian']
# Record is:  [1288, 87, 1326, 120, 'Pedestrian']
# 12 1 2 0
# Ground Truth:  12
# processing time:  4.1274778842926025
# Record is:  [1330, 111, 1372, 149, 'Pedestrian']
# Record is:  [1288, 148, 1331, 185, 'Pedestrian']
# Record is:  [1413, 145, 1464, 194, 'Pedestrian']
# Record is:  [1291, 114, 1326, 150, 'Pedestrian']
# Record is:  [1328, 138, 1366, 172, 'Pedestrian']
# Record is:  [1443, 113, 1498, 163, 'Pedestrian']
# Record is:  [1275, 59, 1327, 97, 'Pedestrian']
# Record is:  [1054, 678, 1121, 753, 'Pedestrian']
# Record is:  [584, 364, 640, 407, 'Pedestrian']
# Record is:  [360, 309, 412, 363, 'Pedestrian']
# Record is:  [1652, 876, 1747, 949, 'Biker']
# Record is:  [1451, 738, 1507, 775, 'Pedestrian']
# Record is:  [1541, 882, 1600, 925, 'Pedestrian']
# 12 0 1 0
# Ground Truth:  12
# processing time:  4.187922716140747
# Record is:  [1287, 147, 1336, 192, 'Pedestrian']
# Record is:  [1328, 147, 1375, 184, 'Pedestrian']
# Record is:  [1333, 112, 1374, 148, 'Pedestrian']
# Record is:  [1278, 52, 1328, 93, 'Pedestrian']
# Record is:  [1286, 115, 1335, 155, 'Pedestrian']
# Record is:  [1441, 104, 1520, 163, 'Pedestrian']
# Record is:  [1410, 141, 1463, 200, 'Pedestrian']
# Record is:  [1122, 888, 1184, 930, 'Pedestrian']
# Record is:  [588, 364, 640, 409, 'Pedestrian']
# Record is:  [1130, 845, 1186, 890, 'Pedestrian']
# Record is:  [1467, 734, 1517, 777, 'Pedestrian']
# Record is:  [1285, 88, 1330, 123, 'Pedestrian']
# 11 0 1 0
# Ground Truth:  11
# processing time:  4.513116121292114
# Record is:  [1292, 121, 1338, 155, 'Pedestrian']
# Record is:  [1332, 108, 1387, 138, 'Pedestrian']
# Record is:  [1295, 161, 1340, 193, 'Pedestrian']
# Record is:  [1447, 111, 1496, 151, 'Pedestrian']
# Record is:  [1288, 90, 1335, 116, 'Pedestrian']
# Record is:  [1417, 156, 1464, 189, 'Pedestrian']
# Record is:  [1408, 178, 1458, 215, 'Pedestrian']
# Record is:  [1292, 56, 1333, 90, 'Pedestrian']
# Record is:  [1454, 738, 1510, 776, 'Pedestrian']
# Record is:  [588, 344, 656, 422, 'Pedestrian']
# Record is:  [754, 829, 803, 894, 'Biker']
# Record is:  [827, 921, 866, 969, 'Pedestrian']
# Record is:  [1337, 145, 1374, 178, 'Pedestrian']
# Record is:  [879, 915, 949, 969, 'Pedestrian']
# Record is:  [417, 365, 476, 414, 'Pedestrian']
# Record is:  [623, 142, 710, 208, 'Biker']
# Record is:  [626, 206, 673, 265, 'Pedestrian']
# 17 0 0 0
# Ground Truth:  17
# processing time:  3.9201924800872803
# Record is:  [1258, 1621, 1297, 1712, 'Pedestrian']
# Record is:  [162, 941, 326, 1153, 'Biker']
# Record is:  [0, 1150, 135, 1292, 'Pedestrian']
# Record is:  [833, 738, 962, 881, 'Pedestrian']
# Record is:  [227, 828, 378, 983, 'Biker']
# Record is:  [150, 948, 268, 1178, 'Skater']
# Record is:  [906, 1845, 943, 1913, 'Pedestrian']
# Record is:  [998, 1767, 1031, 1840, 'Pedestrian']
# Record is:  [159, 956, 273, 1181, 'Pedestrian']
# Record is:  [158, 977, 266, 1193, 'Biker']
# 8 2 0 0
# Ground Truth:  7
# processing time:  3.718848705291748
# Record is:  [1376, 200, 1408, 248, 'Pedestrian']
# Record is:  [748, 453, 799, 502, 'Pedestrian']
# Record is:  [458, 467, 497, 514, 'Pedestrian']
# Record is:  [732, 268, 788, 320, 'Pedestrian']
# Record is:  [699, 314, 746, 369, 'Pedestrian']
# Record is:  [1120, 987, 1170, 1033, 'Biker']
# Record is:  [3, 835, 45, 898, 'Pedestrian']
# Record is:  [693, 688, 727, 735, 'Pedestrian']
# Record is:  [1065, 978, 1100, 1010, 'Pedestrian']
# Record is:  [686, 321, 733, 379, 'Pedestrian']
# Record is:  [231, 488, 261, 534, 'Pedestrian']
# 7 1 3 7
# Ground Truth:  15
# processing time:  3.8231661319732666
# Record is:  [700, 341, 739, 397, 'Pedestrian']
# Record is:  [378, 419, 421, 482, 'Biker']
# Record is:  [387, 1029, 444, 1074, 'Biker']
# Record is:  [270, 717, 297, 773, 'Pedestrian']
# Record is:  [866, 656, 906, 699, 'Pedestrian']
# Record is:  [1368, 203, 1405, 248, 'Pedestrian']
# Record is:  [1255, 1038, 1287, 1070, 'Pedestrian']
# Record is:  [1236, 1000, 1281, 1048, 'Biker']
# Record is:  [67, 696, 105, 728, 'Pedestrian']
# Record is:  [1277, 811, 1317, 853, 'Skater']
# Record is:  [108, 771, 132, 813, 'Pedestrian']
# Record is:  [1273, 806, 1323, 862, 'Biker']
# Record is:  [1219, 1039, 1254, 1068, 'Pedestrian']
# 9 2 2 5
# Ground Truth:  15
# processing time:  4.358804941177368
# Record is:  [571, 828, 615, 916, 'Pedestrian']
# Record is:  [481, 1120, 528, 1209, 'Pedestrian']
# 2 0 0 0
# Ground Truth:  2
# processing time:  4.052988290786743
# Record is:  [1332, 107, 1380, 140, 'Pedestrian']
# Record is:  [1293, 124, 1337, 153, 'Pedestrian']
# Record is:  [1332, 144, 1365, 177, 'Pedestrian']
# Record is:  [1291, 89, 1337, 114, 'Pedestrian']
# Record is:  [1441, 111, 1496, 154, 'Pedestrian']
# Record is:  [1294, 162, 1340, 195, 'Pedestrian']
# Record is:  [1294, 57, 1334, 88, 'Pedestrian']
# Record is:  [1408, 163, 1463, 206, 'Pedestrian']
# Record is:  [1419, 156, 1464, 186, 'Pedestrian']
# Record is:  [588, 349, 648, 415, 'Pedestrian']
# Record is:  [1453, 740, 1508, 777, 'Pedestrian']
# Record is:  [378, 24, 431, 88, 'Pedestrian']
# Record is:  [701, 908, 778, 959, 'Pedestrian']
# Record is:  [417, 365, 475, 414, 'Pedestrian']
# Record is:  [508, 591, 608, 659, 'Biker']
# Record is:  [591, 915, 635, 974, 'Pedestrian']
# 16 0 0 0
# Ground Truth:  16
# processing time:  3.80013108253479
# Record is:  [680, 835, 761, 916, 'Biker']
# Record is:  [228, 708, 299, 790, 'Pedestrian']
# Record is:  [1163, 1031, 1259, 1093, 'Biker']
# Record is:  [628, 1153, 681, 1227, 'Pedestrian']
# 4 0 0 0
# Ground Truth:  4
# processing time:  4.218521595001221
# Record is:  [395, 1040, 509, 1141, 'Biker']
# Record is:  [671, 839, 748, 913, 'Biker']
# Record is:  [3, 955, 125, 1066, 'Pedestrian']
# 3 0 0 0
# Ground Truth:  3
# processing time:  3.4891273975372314
# Record is:  [1376, 196, 1408, 249, 'Pedestrian']
# Record is:  [1194, 994, 1259, 1042, 'Biker']
# Record is:  [711, 345, 762, 397, 'Pedestrian']
# Record is:  [842, 987, 890, 1037, 'Biker']
# Record is:  [541, 473, 582, 515, 'Pedestrian']
# Record is:  [730, 266, 787, 321, 'Pedestrian']
# Record is:  [830, 463, 883, 511, 'Biker']
# Record is:  [267, 960, 304, 1004, 'Pedestrian']
# Record is:  [1269, 965, 1304, 1003, 'Pedestrian']
# 6 1 2 9
# Ground Truth:  16
# processing time:  4.077784061431885
# Record is:  [1286, 150, 1330, 187, 'Pedestrian']
# Record is:  [1325, 146, 1381, 186, 'Pedestrian']
# Record is:  [1496, 21, 1567, 78, 'Pedestrian']
# Record is:  [1329, 109, 1374, 151, 'Pedestrian']
# Record is:  [1433, 117, 1491, 163, 'Pedestrian']
# Record is:  [1406, 144, 1464, 191, 'Pedestrian']
# Record is:  [1296, 102, 1332, 152, 'Pedestrian']
# Record is:  [1276, 48, 1323, 102, 'Pedestrian']
# Record is:  [578, 344, 665, 409, 'Pedestrian']
# Record is:  [406, 359, 473, 420, 'Pedestrian']
# Record is:  [1011, 947, 1066, 993, 'Pedestrian']
# Record is:  [1358, 454, 1426, 527, 'Biker']
# 12 0 0 0
# Ground Truth:  12
# processing time:  4.131859064102173
# Record is:  [955, 454, 998, 515, 'Pedestrian']
# Record is:  [1372, 200, 1406, 250, 'Pedestrian']
# Record is:  [1187, 727, 1233, 760, 'Pedestrian']
# Record is:  [1357, 592, 1390, 636, 'Pedestrian']
# Record is:  [698, 338, 739, 386, 'Pedestrian']
# Record is:  [883, 360, 926, 398, 'Pedestrian']
# Record is:  [1188, 862, 1224, 900, 'Pedestrian']
# Record is:  [669, 480, 715, 518, 'Pedestrian']
# Record is:  [826, 1026, 884, 1076, 'Biker']
# Record is:  [1050, 1033, 1119, 1074, 'Biker']
# Record is:  [695, 690, 724, 732, 'Pedestrian']
# Record is:  [761, 297, 813, 338, 'Pedestrian']
# Record is:  [726, 271, 775, 311, 'Pedestrian']
# Record is:  [1056, 1050, 1106, 1074, 'Biker']
# Record is:  [139, 338, 187, 407, 'Pedestrian']
# Record is:  [335, 1024, 385, 1067, 'Biker']
# Record is:  [1184, 718, 1231, 758, 'Biker']
# Record is:  [715, 338, 747, 384, 'Pedestrian']
# 13 2 3 6
# Ground Truth:  18
# processing time:  3.69861102104187
# Record is:  [3, 456, 42, 492, 'Biker']
# Record is:  [456, 353, 503, 407, 'Pedestrian']
# Record is:  [728, 258, 787, 329, 'Pedestrian']
# Record is:  [1144, 870, 1180, 907, 'Pedestrian']
# 1 1 2 8
# Ground Truth:  10
# processing time:  3.9802093505859375
# Record is:  [696, 1826, 737, 1905, 'Pedestrian']
# Record is:  [1159, 136, 1190, 222, 'Pedestrian']
# Record is:  [711, 597, 760, 676, 'Biker']
# Record is:  [544, 1817, 585, 1902, 'Pedestrian']
# Record is:  [471, 1123, 525, 1181, 'Biker']
# Record is:  [779, 993, 816, 1053, 'Biker']
# Record is:  [556, 281, 594, 353, 'Biker']
# Record is:  [654, 1291, 685, 1373, 'Biker']
# Record is:  [625, 1816, 669, 1900, 'Pedestrian']
# Record is:  [630, 1820, 663, 1898, 'Biker']
# Record is:  [688, 1078, 733, 1154, 'Biker']
# Record is:  [759, 655, 798, 721, 'Biker']
# Record is:  [678, 690, 728, 772, 'Biker']
# Record is:  [379, 1078, 431, 1134, 'Biker']
# Record is:  [655, 1358, 696, 1431, 'Biker']
# Record is:  [663, 1231, 704, 1291, 'Biker']
# Record is:  [760, 776, 803, 835, 'Biker']
# Record is:  [955, 999, 987, 1063, 'Pedestrian']
# Record is:  [786, 1159, 829, 1231, 'Skater']
# Record is:  [774, 1143, 828, 1224, 'Biker']
# Record is:  [592, 1126, 630, 1179, 'Biker']
# Record is:  [575, 1116, 635, 1189, 'Biker']
# Record is:  [538, 279, 589, 351, 'Pedestrian']
# Record is:  [945, 993, 978, 1057, 'Pedestrian']
# Record is:  [19, 963, 56, 1006, 'Biker']
# Record is:  [955, 999, 987, 1063, 'Biker']
# Record is:  [679, 691, 729, 772, 'Pedestrian']
# Record is:  [254, 981, 294, 1055, 'Biker']
# 9 10 9 7
# Ground Truth:  24
# processing time:  3.822028160095215
# Record is:  [768, 1274, 861, 1396, 'Biker']
# Record is:  [212, 932, 297, 1050, 'Biker']
# Record is:  [1106, 1132, 1188, 1220, 'Skater']
# Record is:  [1049, 1191, 1124, 1298, 'Biker']
# Record is:  [1000, 1250, 1082, 1347, 'Biker']
# Record is:  [817, 1306, 864, 1393, 'Biker']
# Record is:  [1317, 1115, 1381, 1211, 'Biker']
# Record is:  [378, 515, 435, 612, 'Pedestrian']
# Record is:  [245, 973, 282, 1048, 'Biker']
# Record is:  [212, 933, 296, 1051, 'Pedestrian']
# Record is:  [281, 1542, 324, 1605, 'Pedestrian']
# Record is:  [1012, 1446, 1091, 1577, 'Biker']
# Record is:  [202, 968, 243, 1039, 'Pedestrian']
# Record is:  [1141, 1152, 1183, 1213, 'Biker']
# Record is:  [746, 1281, 820, 1382, 'Biker']
# Record is:  [220, 962, 270, 1049, 'Biker']
# Record is:  [1106, 1132, 1188, 1220, 'Biker']
# 14 2 1 2
# Ground Truth:  13
# processing time:  3.8678016662597656
# Record is:  [1330, 110, 1372, 149, 'Pedestrian']
# Record is:  [1286, 148, 1331, 187, 'Pedestrian']
# Record is:  [1330, 139, 1367, 170, 'Pedestrian']
# Record is:  [1413, 146, 1462, 192, 'Pedestrian']
# Record is:  [1443, 112, 1498, 161, 'Pedestrian']
# Record is:  [1275, 59, 1327, 101, 'Pedestrian']
# Record is:  [1290, 115, 1327, 149, 'Pedestrian']
# Record is:  [1933, 891, 1978, 932, 'Pedestrian']
# Record is:  [360, 324, 410, 374, 'Pedestrian']
# Record is:  [1017, 728, 1097, 810, 'Pedestrian']
# Record is:  [585, 361, 640, 404, 'Pedestrian']
# Record is:  [1522, 871, 1623, 941, 'Biker']
# Record is:  [1543, 920, 1601, 974, 'Pedestrian']
# Record is:  [1929, 926, 1978, 970, 'Pedestrian']
# Record is:  [1449, 737, 1510, 775, 'Pedestrian']
# 14 0 1 0
# Ground Truth:  14
# processing time:  4.469010591506958
# Record is:  [1322, 138, 1373, 176, 'Pedestrian']
# Record is:  [1291, 116, 1332, 152, 'Pedestrian']
# Record is:  [1332, 109, 1378, 150, 'Pedestrian']
# Record is:  [1203, 68, 1264, 119, 'Pedestrian']
# Record is:  [1432, 111, 1501, 159, 'Pedestrian']
# Record is:  [1280, 145, 1333, 185, 'Pedestrian']
# Record is:  [1274, 83, 1330, 124, 'Pedestrian']
# Record is:  [799, 915, 889, 976, 'Biker']
# Record is:  [1402, 80, 1461, 129, 'Pedestrian']
# Record is:  [1412, 146, 1467, 197, 'Pedestrian']
# Record is:  [1285, 40, 1339, 94, 'Pedestrian']
# Record is:  [636, 828, 719, 891, 'Pedestrian']
# Record is:  [1525, 799, 1617, 845, 'Pedestrian']
# Record is:  [1398, 106, 1433, 147, 'Pedestrian']
# 13 0 1 1
# Ground Truth:  14
# processing time:  3.857114315032959
# Record is:  [1328, 146, 1377, 184, 'Pedestrian']
# Record is:  [1291, 149, 1332, 187, 'Pedestrian']
# Record is:  [1295, 112, 1334, 152, 'Pedestrian']
# Record is:  [1335, 111, 1376, 150, 'Pedestrian']
# Record is:  [1433, 118, 1495, 164, 'Pedestrian']
# Record is:  [1409, 145, 1468, 197, 'Pedestrian']
# Record is:  [1270, 55, 1329, 99, 'Pedestrian']
# Record is:  [406, 355, 483, 420, 'Pedestrian']
# Record is:  [992, 766, 1062, 827, 'Pedestrian']
# Record is:  [161, 637, 249, 715, 'Biker']
# Record is:  [288, 969, 361, 1045, 'Pedestrian']
# Record is:  [1417, 763, 1492, 826, 'Pedestrian']
# Record is:  [586, 352, 655, 414, 'Pedestrian']
# 13 0 0 1
# Ground Truth:  14
# processing time:  3.6233532428741455
# Record is:  [1153, 340, 1195, 393, 'Pedestrian']
# Record is:  [1025, 847, 1055, 879, 'Pedestrian']
# Record is:  [711, 336, 749, 383, 'Pedestrian']
# Record is:  [103, 1020, 148, 1067, 'Pedestrian']
# Record is:  [1036, 909, 1072, 942, 'Pedestrian']
# Record is:  [417, 957, 455, 1018, 'Biker']
# Record is:  [666, 285, 701, 342, 'Pedestrian']
# Record is:  [1022, 878, 1063, 914, 'Pedestrian']
# Record is:  [1035, 845, 1065, 879, 'Pedestrian']
# Record is:  [247, 1021, 288, 1057, 'Pedestrian']
# Record is:  [1216, 998, 1254, 1024, 'Pedestrian']
# Record is:  [3, 866, 36, 910, 'Pedestrian']
# 8 2 2 1
# Ground Truth:  10
# processing time:  3.748671531677246
# Record is:  [1373, 203, 1408, 250, 'Pedestrian']
# Record is:  [295, 573, 326, 613, 'Pedestrian']
# Record is:  [694, 336, 732, 386, 'Pedestrian']
# Record is:  [39, 1029, 74, 1068, 'Pedestrian']
# Record is:  [295, 575, 326, 612, 'Biker']
# Record is:  [1027, 874, 1071, 927, 'Pedestrian']
# Record is:  [464, 809, 502, 841, 'Pedestrian']
# Record is:  [54, 326, 99, 381, 'Biker']
# 5 1 2 10
# Ground Truth:  15
# processing time:  3.7157773971557617
# Record is:  [165, 746, 227, 884, 'Pedestrian']
# Record is:  [391, 683, 443, 771, 'Pedestrian']
# Record is:  [391, 683, 443, 771, 'Biker']
# 2 1 0 0
# Ground Truth:  2
# processing time:  3.4338018894195557
# Record is:  [1297, 941, 1350, 979, 'Pedestrian']
# Record is:  [1162, 937, 1223, 986, 'Biker']
# Record is:  [1297, 942, 1350, 979, 'Biker']
# Record is:  [707, 315, 742, 363, 'Pedestrian']
# Record is:  [460, 353, 501, 412, 'Pedestrian']
# Record is:  [690, 688, 726, 738, 'Pedestrian']
# Record is:  [301, 192, 339, 231, 'Pedestrian']
# Record is:  [1299, 956, 1346, 999, 'Biker']
# 4 2 2 3
# Ground Truth:  7
# processing time:  4.271852016448975
# Record is:  [1290, 151, 1331, 189, 'Pedestrian']
# Record is:  [1330, 142, 1368, 174, 'Pedestrian']
# Record is:  [1332, 111, 1373, 148, 'Pedestrian']
# Record is:  [1282, 56, 1328, 92, 'Pedestrian']
# Record is:  [1289, 116, 1330, 152, 'Pedestrian']
# Record is:  [1413, 148, 1466, 201, 'Pedestrian']
# Record is:  [1437, 114, 1501, 161, 'Pedestrian']
# Record is:  [1634, 922, 1712, 961, 'Pedestrian']
# Record is:  [849, 998, 912, 1054, 'Pedestrian']
# Record is:  [1284, 87, 1328, 122, 'Pedestrian']
# Record is:  [596, 866, 714, 954, 'Biker']
# Record is:  [1467, 733, 1517, 773, 'Pedestrian']
# Record is:  [582, 350, 651, 412, 'Pedestrian']
# Record is:  [1732, 672, 1838, 740, 'Pedestrian']
# 10 0 4 2
# Ground Truth:  12
# processing time:  4.264403581619263
# Record is:  [1178, 936, 1221, 986, 'Biker']
# Record is:  [654, 316, 698, 367, 'Pedestrian']
# Record is:  [385, 974, 437, 1037, 'Biker']
# Record is:  [341, 657, 380, 706, 'Pedestrian']
# Record is:  [733, 270, 787, 317, 'Pedestrian']
# Record is:  [331, 606, 359, 653, 'Pedestrian']
# Record is:  [1120, 990, 1174, 1050, 'Biker']
# Record is:  [460, 351, 500, 411, 'Pedestrian']
# Record is:  [287, 735, 326, 791, 'Biker']
# Record is:  [1380, 201, 1409, 248, 'Pedestrian']
# Record is:  [314, 837, 340, 881, 'Pedestrian']
# Record is:  [395, 983, 433, 1025, 'Biker']
# Record is:  [1121, 1004, 1167, 1038, 'Biker']
# 9 2 2 8
# Ground Truth:  17
# processing time:  3.970583915710449
# Record is:  [124, 742, 188, 881, 'Pedestrian']
# Record is:  [479, 680, 534, 770, 'Pedestrian']
# 2 0 0 0
# Ground Truth:  2
# processing time:  3.895660638809204
# Record is:  [679, 1067, 740, 1137, 'Biker']
# Record is:  [1121, 1145, 1182, 1239, 'Biker']
# Record is:  [1100, 1139, 1175, 1238, 'Skater']
# 2 1 0 0
# Ground Truth:  2
# processing time:  4.0448174476623535
# Record is:  [1122, 938, 1180, 1042, 'Pedestrian']
# Record is:  [141, 676, 211, 763, 'Pedestrian']
# Record is:  [535, 758, 584, 834, 'Pedestrian']
# Record is:  [223, 634, 304, 734, 'Biker']
# 3 0 1 0
# Ground Truth:  3
# processing time:  3.855600118637085
# Record is:  [1288, 148, 1333, 192, 'Pedestrian']
# Record is:  [1326, 148, 1378, 184, 'Pedestrian']
# Record is:  [1334, 109, 1376, 149, 'Pedestrian']
# Record is:  [1408, 141, 1466, 205, 'Pedestrian']
# Record is:  [1280, 85, 1330, 124, 'Pedestrian']
# Record is:  [1288, 116, 1338, 158, 'Pedestrian']
# Record is:  [1274, 51, 1331, 95, 'Pedestrian']
# Record is:  [1437, 113, 1502, 163, 'Pedestrian']
# Record is:  [796, 863, 870, 915, 'Pedestrian']
# Record is:  [584, 362, 638, 409, 'Pedestrian']
# Record is:  [803, 821, 864, 867, 'Pedestrian']
# Record is:  [1489, 402, 1573, 469, 'Pedestrian']
# Record is:  [1456, 738, 1516, 774, 'Pedestrian']
# Record is:  [404, 358, 489, 420, 'Pedestrian']
# 12 0 2 0
# Ground Truth:  12
# processing time:  3.556037187576294
# Record is:  [1309, 976, 1352, 1023, 'Pedestrian']
# Record is:  [703, 335, 746, 387, 'Pedestrian']
# Record is:  [854, 869, 901, 912, 'Pedestrian']
# Record is:  [391, 429, 433, 491, 'Biker']
# Record is:  [862, 896, 902, 932, 'Pedestrian']
# Record is:  [992, 409, 1037, 465, 'Biker']
# Record is:  [864, 852, 896, 897, 'Pedestrian']
# Record is:  [391, 953, 432, 994, 'Pedestrian']
# 6 2 0 2
# Ground Truth:  10
# processing time:  3.7842934131622314
# Record is:  [514, 444, 558, 491, 'Pedestrian']
# Record is:  [1217, 766, 1256, 813, 'Pedestrian']
# Record is:  [707, 339, 742, 385, 'Pedestrian']
# Record is:  [694, 686, 728, 735, 'Pedestrian']
# Record is:  [610, 738, 640, 774, 'Pedestrian']
# Record is:  [1377, 203, 1408, 255, 'Pedestrian']
# Record is:  [1126, 1000, 1183, 1057, 'Biker']
# Record is:  [738, 268, 793, 309, 'Pedestrian']
# 5 1 2 5
# Ground Truth:  11
# processing time:  3.9903781414031982
# Record is:  [1288, 150, 1332, 189, 'Pedestrian']
# Record is:  [1327, 110, 1371, 148, 'Pedestrian']
# Record is:  [1325, 140, 1371, 175, 'Pedestrian']
# Record is:  [1290, 115, 1328, 150, 'Pedestrian']
# Record is:  [1437, 113, 1506, 162, 'Pedestrian']
# Record is:  [1269, 52, 1331, 92, 'Pedestrian']
# Record is:  [1412, 149, 1463, 198, 'Pedestrian']
# Record is:  [1015, 893, 1108, 952, 'Biker']
# Record is:  [582, 351, 652, 408, 'Pedestrian']
# Record is:  [1464, 737, 1516, 774, 'Pedestrian']
# Record is:  [914, 882, 971, 935, 'Pedestrian']
# Record is:  [1750, 877, 1838, 925, 'Pedestrian']
# Record is:  [1287, 86, 1325, 123, 'Pedestrian']
# Record is:  [1759, 916, 1844, 958, 'Pedestrian']
# Record is:  [1249, 54, 1308, 93, 'Pedestrian']
# 14 0 1 1
# Ground Truth:  14

# %%
print(total_true_positive, total_class_mismatch, total_false_positive, total_false_negative, total_gt)
# Out:
# 656 66 85 174 845

# %% [markdown]
# gt_ann = get_gt_annotations(filepath)
# print(gt_ann)
# im = cv2.imread(filepath)
# for each_ann in gt_ann:
#     cv2.rectangle(im, (each_ann[0],each_ann[1]),(each_ann[2],each_ann[3]),(0,0,255),3)
# cv2.imwrite('examples/results_test/pred_gt.jpg', im)

# %%
# 4763 687 2192 1067 5854

precision = total_true_positive/(total_true_positive+total_false_positive+total_class_mismatch)
recall = total_true_positive/(total_true_positive+ total_false_negative)
f1_score = 2*(precision * recall)/(precision + recall)
Accuracy=(total_true_positive+total_class_mismatch)/(total_true_positive+total_false_positive+total_class_mismatch+total_false_negative)
print("Accuracy:",Accuracy)
# Out:
# Accuracy: 0.7359836901121305

# %%
file1 = open(r"accuracy.txt", "w+")

# %%
file1.write(str(Accuracy))
# Out:
# 18
